# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from pathlib import Path
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
# Load data 
base_folder = Path.cwd()
clean_folder = base_folder.parent / 'data/clean_data'
df_train = pd.read_csv(f'{clean_folder}/df_train_selected.csv')
df_test = pd.read_csv(f'{clean_folder}/df_test_selected.csv')

# %%
# Create feature variables and target variables
X = df_train.drop(columns=['ID_CLIENTE', 'SAFRA_REF', 'INADIMPLENTE'])
y = df_train['INADIMPLENTE']

# Split train and validation set
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=17, stratify=y)

# %%
# Define the parameter grid to search over
param_grid = {
    'n_estimators': [100, 250, 500],
    'criterion': ['entropy', 'log_loss'],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'class_weight': ['balanced', None]
}

# Set up the grid search with 5-fold cross-validation
grid_search = GridSearchCV(
    estimator=RandomForestClassifier(random_state=19, n_jobs=16),
    param_grid=param_grid,
    # cv=5,  # 5-fold cross-validation
    scoring='f1',  # Use F1 score as the evaluation metric
    n_jobs=-1,  # Use all available cores for parallel processing
    verbose=2
)

# Fit the model using grid search
grid_search.fit(X_train, y_train)

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Print the best parameters
print(f"Best parameters found by GridSearchCV: {best_params}")
print(f"Best cross-validated F1 score: {best_score}")

# Evaluate model on validation set using the best parameters
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_val)
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  14.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  14.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  14.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  14.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  14.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  32.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  32.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  32.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  31.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  32.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  14.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  14.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  15.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  15.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  13.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  33.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  33.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  32.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  32.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  33.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  14.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  14.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  14.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  13.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  13.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  35.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  34.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  34.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  34.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  29.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  13.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  15.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  15.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  16.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  33.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  32.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  33.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  15.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  31.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  32.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  15.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  14.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  14.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  15.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  35.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  35.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  33.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  34.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  33.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  16.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  15.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  16.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  16.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  15.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=250; total time=  32.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=250; total time=  31.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=250; total time=  31.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=250; total time=  29.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=250; total time=  30.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  12.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  13.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  12.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  13.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  13.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  59.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  59.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 1.0min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time= 1.0min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  58.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=  29.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=  28.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=  27.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=  28.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=  28.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  12.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  13.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  13.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  13.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  14.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  58.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  60.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  58.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  59.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time= 1.0min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=  30.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=  30.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=  30.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=  29.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=  29.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  11.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  11.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  11.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  11.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  11.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=  54.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=  55.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=  54.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=  54.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=  54.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=  25.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=  25.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=  25.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=  28.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  12.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=  28.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  11.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  10.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  10.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   9.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  56.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  22.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  22.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  57.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  56.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  56.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  20.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  57.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  24.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  14.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  25.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  17.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  17.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  18.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  13.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  56.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  57.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  57.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  57.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  57.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  24.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  23.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  19.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  19.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  19.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   9.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   9.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   9.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   9.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   9.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  41.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  40.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  41.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  41.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  21.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  41.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  20.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  20.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  19.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  19.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   9.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   9.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   9.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   9.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   9.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  40.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  40.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  40.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  40.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  20.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  40.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  20.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  18.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  20.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   9.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  20.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   9.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   9.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   9.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   9.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  39.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  40.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  40.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  40.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  41.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  19.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  19.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  19.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  19.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  20.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   9.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   8.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   9.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   9.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   9.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  41.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  41.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  41.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  41.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  41.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=250; total time=  20.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=250; total time=  19.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=250; total time=  19.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=250; total time=  19.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=250; total time=  19.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   9.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   9.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   9.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   9.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  39.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  40.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  40.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  40.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  41.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=  20.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=  19.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=  19.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=  20.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=  20.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   9.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   9.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   9.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   9.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   9.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  40.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  40.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  40.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  41.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  41.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=  20.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=  19.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=  19.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=  19.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=  19.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   9.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   9.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   9.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   9.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   9.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=  41.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=  41.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=  41.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=  42.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=  22.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=  42.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=  20.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=  20.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=  20.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=  20.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  13.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  13.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  14.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  13.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  42.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  12.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  41.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  41.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  41.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  41.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  32.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  34.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  33.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  34.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=250; total time=  33.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  13.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  14.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  14.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  12.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  13.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.1min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  30.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time= 1.0min
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  59.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  28.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  28.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  28.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  27.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  11.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  12.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  11.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  12.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  12.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  55.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  55.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  29.8s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  56.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  27.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  54.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=  54.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  26.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  27.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.1s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  26.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.0s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  53.9s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  54.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  54.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  55.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=  54.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  28.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  27.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  27.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  26.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  12.7s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  26.3s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  12.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  12.4s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  12.6s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  12.5s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  54.2s
# [CV] END class_weight=balanced, criterion=entropy, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  54.6s
# ...
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  43.5s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=250; total time=  43.9s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  20.3s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  19.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  21.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  20.8s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  21.2s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.4min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.4min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.4min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.4min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time= 1.4min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  38.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  38.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  38.6s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  38.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=250; total time=  36.2s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.6s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  13.2s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  13.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  31.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  30.9s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  30.8s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  28.6s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=250; total time=  28.6s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  13.1s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  12.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  13.1s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  13.2s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  13.3s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  58.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  59.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  59.2s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  59.9s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=  59.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  29.9s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  29.8s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  28.1s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  28.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=250; total time=  27.9s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  12.8s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  12.9s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  12.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  13.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  13.1s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  58.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  58.1s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  56.9s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  58.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=  58.5s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=250; total time=  28.6s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=250; total time=  28.3s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=250; total time=  28.3s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=250; total time=  27.9s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=250; total time=  28.6s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  12.2s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  12.9s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  13.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  12.6s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  12.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  57.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  57.8s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  57.8s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  57.5s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=  58.9s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=  28.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=  28.2s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=  26.8s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=  27.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=250; total time=  26.9s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  12.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  12.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  12.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  13.2s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  13.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  56.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  56.3s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  56.1s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  57.3s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=  56.5s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=  28.8s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=  28.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=  27.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=  27.3s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=  27.2s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  12.8s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  12.8s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  12.2s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  12.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  13.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=  56.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=  57.1s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=  57.1s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=  57.3s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=  29.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=  57.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=  29.6s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=  29.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=  26.6s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=  25.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  43.1s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  43.3s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  41.3s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  39.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=  36.2s
# Best parameters found by GridSearchCV: {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': 30, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 500}
# Best cross-validated F1 score: 0.6839804851195418

# %%
# Compute performance metrics and confusion matrix
accuracy = accuracy_score(y_val, y_pred)
precision = precision_score(y_val, y_pred)
recall = recall_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred)
conf_matrix = confusion_matrix(y_val, y_pred)

# Print results
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1: {f1}')
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# Accuracy: 0.9593721741377083
# Precision: 0.7220602526724975
# Recall: 0.6841620626151013
# F1: 0.7026004728132388
# Confusion Matrix:
# [[14110   286]
#  [  343   743]]
