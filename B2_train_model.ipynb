# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from pathlib import Path
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
# Load data 
base_folder = Path.cwd()
clean_folder = base_folder.parent / 'data/clean_data'
df_train = pd.read_csv(f'{clean_folder}/df_train.csv')
df_test = pd.read_csv(f'{clean_folder}/df_test.csv')

# %%
df_train.columns
# Out:
# Index(['ID_CLIENTE', 'SAFRA_REF', 'NO_FUNCIONARIOS', 'RENDA_MES_ANTERIOR_LOG',
#        'PJ', 'SEGMENTO_INDUSTRIAL', 'PORTE', 'REGIAO',
#        'DATA_EMISSAO_DOCUMENTO', 'DATA_PAGAMENTO', 'DATA_VENCIMENTO', 'TAXA',
#        'VALOR_A_PAGAR_LOG', 'INADIMPLENTE', 'DATA_EMISSAO_DOCUMENTO_year',
#        'DATA_EMISSAO_DOCUMENTO_month', 'DATA_PAGAMENTO_year',
#        'DATA_PAGAMENTO_month', 'DATA_VENCIMENTO_year',
#        'DATA_VENCIMENTO_month'],
#       dtype='object')

# %%
df_train = df_train.drop(columns=['DATA_PAGAMENTO', 'DATA_EMISSAO_DOCUMENTO', 'DATA_VENCIMENTO', 'DATA_PAGAMENTO_year', 'DATA_PAGAMENTO_month']).copy()
df_test = df_test.drop(columns=['DATA_EMISSAO_DOCUMENTO', 'DATA_VENCIMENTO']).copy()

# %%
df_test.columns, df_train.columns
# Out:
# (Index(['ID_CLIENTE', 'SAFRA_REF', 'NO_FUNCIONARIOS', 'RENDA_MES_ANTERIOR_LOG',
#         'PJ', 'SEGMENTO_INDUSTRIAL', 'PORTE', 'REGIAO', 'TAXA',
#         'VALOR_A_PAGAR_LOG', 'DATA_EMISSAO_DOCUMENTO_year',
#         'DATA_EMISSAO_DOCUMENTO_month', 'DATA_VENCIMENTO_year',
#         'DATA_VENCIMENTO_month'],
#        dtype='object'),
#  Index(['ID_CLIENTE', 'SAFRA_REF', 'NO_FUNCIONARIOS', 'RENDA_MES_ANTERIOR_LOG',
#         'PJ', 'SEGMENTO_INDUSTRIAL', 'PORTE', 'REGIAO', 'TAXA',
#         'VALOR_A_PAGAR_LOG', 'INADIMPLENTE', 'DATA_EMISSAO_DOCUMENTO_year',
#         'DATA_EMISSAO_DOCUMENTO_month', 'DATA_VENCIMENTO_year',
#         'DATA_VENCIMENTO_month'],
#        dtype='object'))

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77408 entries, 0 to 77407
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID_CLIENTE                    77408 non-null  float64
#  1   SAFRA_REF                     77408 non-null  object
#  2   NO_FUNCIONARIOS               77408 non-null  float64
#  3   RENDA_MES_ANTERIOR_LOG        77408 non-null  float64
#  4   PJ                            77408 non-null  float64
#  5   SEGMENTO_INDUSTRIAL           77408 non-null  int64
#  6   PORTE                         77408 non-null  int64
#  7   REGIAO                        77408 non-null  int64
#  8   TAXA                          77408 non-null  float64
#  9   VALOR_A_PAGAR_LOG             77408 non-null  float64
#  10  INADIMPLENTE                  77408 non-null  float64
#  11  DATA_EMISSAO_DOCUMENTO_year   77408 non-null  int64
#  12  DATA_EMISSAO_DOCUMENTO_month  77408 non-null  int64
#  13  DATA_VENCIMENTO_year          77408 non-null  int64
#  14  DATA_VENCIMENTO_month         77408 non-null  int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 8.9+ MB

# %%
df_train.drop(columns=['ID_CLIENTE', 'SAFRA_REF']).corr()
# Out:
#                               NO_FUNCIONARIOS  RENDA_MES_ANTERIOR_LOG  \
# NO_FUNCIONARIOS                      1.000000               -0.003017
# RENDA_MES_ANTERIOR_LOG              -0.003017                1.000000
# PJ                                  -0.000182                0.140796
# SEGMENTO_INDUSTRIAL                 -0.035745               -0.026573
# PORTE                               -0.157987               -0.002632
# REGIAO                               0.029764                0.047571
# TAXA                                 0.012731                0.001790
# VALOR_A_PAGAR_LOG                   -0.000237                0.043702
# INADIMPLENTE                        -0.008789               -0.120930
# DATA_EMISSAO_DOCUMENTO_year          0.298558                0.002131
# DATA_EMISSAO_DOCUMENTO_month        -0.141595                0.004584
# DATA_VENCIMENTO_year                 0.289330                0.000424
# DATA_VENCIMENTO_month               -0.101590                0.006972
#
#                                     PJ  SEGMENTO_INDUSTRIAL     PORTE  \
# NO_FUNCIONARIOS              -0.000182            -0.035745 -0.157987
# RENDA_MES_ANTERIOR_LOG        0.140796            -0.026573 -0.002632
# PJ                            1.000000            -0.044576 -0.012191
# SEGMENTO_INDUSTRIAL          -0.044576             1.000000  0.060449
# PORTE                        -0.012191             0.060449  1.000000
# REGIAO                        0.047481            -0.028372 -0.034705
# TAXA                          0.002885             0.005605  0.011457
# VALOR_A_PAGAR_LOG             0.024601            -0.081765  0.002292
# INADIMPLENTE                 -0.025033             0.072889  0.052010
# DATA_EMISSAO_DOCUMENTO_year  -0.004206            -0.036793 -0.016132
# DATA_EMISSAO_DOCUMENTO_month  0.000992             0.011609  0.005433
# DATA_VENCIMENTO_year         -0.005303            -0.032542 -0.009399
# DATA_VENCIMENTO_month         0.002997             0.010947  0.003824
#
#                                 REGIAO      TAXA  VALOR_A_PAGAR_LOG  \
# NO_FUNCIONARIOS               0.029764  0.012731          -0.000237
# RENDA_MES_ANTERIOR_LOG        0.047571  0.001790           0.043702
# PJ                            0.047481  0.002885           0.024601
# SEGMENTO_INDUSTRIAL          -0.028372  0.005605          -0.081765
# PORTE                        -0.034705  0.011457           0.002292
# REGIAO                        1.000000  0.000640           0.027886
# TAXA                          0.000640  1.000000          -0.016713
# VALOR_A_PAGAR_LOG             0.027886 -0.016713           1.000000
# INADIMPLENTE                 -0.114970  0.012032          -0.299454
# DATA_EMISSAO_DOCUMENTO_year   0.001178  0.007426           0.038654
# DATA_EMISSAO_DOCUMENTO_month -0.000351  0.004466          -0.014056
# DATA_VENCIMENTO_year          0.000220  0.012189           0.028723
# DATA_VENCIMENTO_month        -0.002446 -0.008566           0.003121
#
#                               INADIMPLENTE  DATA_EMISSAO_DOCUMENTO_year  \
# NO_FUNCIONARIOS                  -0.008789                     0.298558
# RENDA_MES_ANTERIOR_LOG           -0.120930                     0.002131
# PJ                               -0.025033                    -0.004206
# SEGMENTO_INDUSTRIAL               0.072889                    -0.036793
# PORTE                             0.052010                    -0.016132
# REGIAO                           -0.114970                     0.001178
# TAXA                              0.012032                     0.007426
# VALOR_A_PAGAR_LOG                -0.299454                     0.038654
# INADIMPLENTE                      1.000000                     0.002633
# DATA_EMISSAO_DOCUMENTO_year       0.002633                     1.000000
# DATA_EMISSAO_DOCUMENTO_month     -0.022199                    -0.455491
# DATA_VENCIMENTO_year              0.019344                     0.960360
# DATA_VENCIMENTO_month            -0.047267                    -0.316201
#
#                               DATA_EMISSAO_DOCUMENTO_month  \
# NO_FUNCIONARIOS                                  -0.141595
# RENDA_MES_ANTERIOR_LOG                            0.004584
# PJ                                                0.000992
# SEGMENTO_INDUSTRIAL                               0.011609
# PORTE                                             0.005433
# REGIAO                                           -0.000351
# TAXA                                              0.004466
# VALOR_A_PAGAR_LOG                                -0.014056
# INADIMPLENTE                                     -0.022199
# DATA_EMISSAO_DOCUMENTO_year                      -0.455491
# DATA_EMISSAO_DOCUMENTO_month                      1.000000
# DATA_VENCIMENTO_year                             -0.347202
# DATA_VENCIMENTO_month                             0.654997
#
#                               DATA_VENCIMENTO_year  DATA_VENCIMENTO_month
# NO_FUNCIONARIOS                           0.289330              -0.101590
# RENDA_MES_ANTERIOR_LOG                    0.000424               0.006972
# PJ                                       -0.005303               0.002997
# SEGMENTO_INDUSTRIAL                      -0.032542               0.010947
# PORTE                                    -0.009399               0.003824
# REGIAO                                    0.000220              -0.002446
# TAXA                                      0.012189              -0.008566
# VALOR_A_PAGAR_LOG                         0.028723               0.003121
# INADIMPLENTE                              0.019344              -0.047267
# DATA_EMISSAO_DOCUMENTO_year               0.960360              -0.316201
# DATA_EMISSAO_DOCUMENTO_month             -0.347202               0.654997
# DATA_VENCIMENTO_year                      1.000000              -0.430167
# DATA_VENCIMENTO_month                    -0.430167               1.000000

# %%
df_train[['DATA_VENCIMENTO_year', 'DATA_EMISSAO_DOCUMENTO_year', 'DATA_EMISSAO_DOCUMENTO_month', 'DATA_VENCIMENTO_month']].corr()
# Out:
#                               DATA_VENCIMENTO_year  \
# DATA_VENCIMENTO_year                      1.000000
# DATA_EMISSAO_DOCUMENTO_year               0.960360
# DATA_EMISSAO_DOCUMENTO_month             -0.347202
# DATA_VENCIMENTO_month                    -0.430167
#
#                               DATA_EMISSAO_DOCUMENTO_year  \
# DATA_VENCIMENTO_year                             0.960360
# DATA_EMISSAO_DOCUMENTO_year                      1.000000
# DATA_EMISSAO_DOCUMENTO_month                    -0.455491
# DATA_VENCIMENTO_month                           -0.316201
#
#                               DATA_EMISSAO_DOCUMENTO_month  \
# DATA_VENCIMENTO_year                             -0.347202
# DATA_EMISSAO_DOCUMENTO_year                      -0.455491
# DATA_EMISSAO_DOCUMENTO_month                      1.000000
# DATA_VENCIMENTO_month                             0.654997
#
#                               DATA_VENCIMENTO_month
# DATA_VENCIMENTO_year                      -0.430167
# DATA_EMISSAO_DOCUMENTO_year               -0.316201
# DATA_EMISSAO_DOCUMENTO_month               0.654997
# DATA_VENCIMENTO_month                      1.000000

# %%
# Create feature variables and target variables
X = df_train.drop(columns=['ID_CLIENTE', 'SAFRA_REF', 'INADIMPLENTE'])
y = df_train['INADIMPLENTE']

# Split train and validation set
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=17, stratify=y)

# %%
# Define the parameter grid to search over
param_grid = {
    'n_estimators': [100, 256, 512],
    'criterion': ['gini', 'entropy', 'log_loss'],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'class_weight': ['balanced', None]
}

# Set up the grid search with 5-fold cross-validation
grid_search = GridSearchCV(
    estimator=RandomForestClassifier(random_state=19, n_jobs=16),
    param_grid=param_grid,
    cv=5,  # 5-fold cross-validation
    scoring='f1',  # Use F1 score as the evaluation metric
    n_jobs=-1,  # Use all available cores for parallel processing
    verbose=2
)

# Fit the model using grid search
grid_search.fit(X_train, y_train)

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Print the best parameters
print(f"Best parameters found by GridSearchCV: {best_params}")
print(f"Best cross-validated F1 score: {best_score}")

# Evaluate model on validation set using the best parameters
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_val)
# Out:
# Fitting 5 folds for each of 648 candidates, totalling 3240 fits
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  11.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  11.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  11.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  11.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  11.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=256; total time=  25.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=256; total time=  25.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=256; total time=  26.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  11.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=256; total time=  26.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=256; total time=  26.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  11.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  11.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  11.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  11.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=512; total time=  53.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=512; total time=  54.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=512; total time=  54.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=256; total time=  27.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=256; total time=  28.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=512; total time=  55.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=512; total time=  55.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=256; total time=  26.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=256; total time=  26.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=256; total time=  26.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  11.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  11.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  11.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  11.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  12.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time=  54.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time=  54.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time=  54.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  27.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time=  55.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time=  55.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  27.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  28.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  29.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  13.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  28.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  11.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time=  59.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time=  59.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time= 1.0min
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time=  59.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time= 1.0min
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  30.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  29.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  29.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  11.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  27.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  27.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  12.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  14.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  13.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  13.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time=  57.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time=  57.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time=  57.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time=  58.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time=  58.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=256; total time=  27.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=256; total time=  28.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=256; total time=  26.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=256; total time=  26.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  11.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=256; total time=  26.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  12.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  11.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  12.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  11.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=512; total time=  54.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=512; total time=  54.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=512; total time=  55.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=512; total time=  55.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=512; total time=  56.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=256; total time=  27.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=256; total time=  26.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=256; total time=  26.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=256; total time=  26.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=256; total time=  26.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  11.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  11.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  10.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=512; total time=  50.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=512; total time=  50.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=512; total time=  51.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=512; total time=  51.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=2, min_samples_split=10, n_estimators=512; total time=  52.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=256; total time=  24.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=256; total time=  24.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=256; total time=  25.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=256; total time=  25.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=256; total time=  24.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  11.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  11.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  10.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  11.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  10.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=512; total time=  50.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=512; total time=  51.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=512; total time=  51.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=512; total time=  51.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=256; total time=  25.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=2, n_estimators=512; total time=  50.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=256; total time=  25.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=256; total time=  24.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=256; total time=  24.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=256; total time=  24.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  10.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  10.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  10.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  10.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  10.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=512; total time=  50.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=512; total time=  49.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=512; total time=  50.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=512; total time=  51.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=512; total time=  51.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=256; total time=  24.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=256; total time=  24.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=256; total time=  24.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=256; total time=  25.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   8.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=256; total time=  24.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   9.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   8.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   8.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   8.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=512; total time=  49.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=256; total time=  20.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=512; total time=  50.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=256; total time=  20.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=512; total time=  49.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=512; total time=  49.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=None, min_samples_leaf=4, min_samples_split=10, n_estimators=512; total time=  50.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=256; total time=  19.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   8.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=256; total time=  18.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=256; total time=  18.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   8.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   8.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   8.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   8.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=512; total time=  39.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=512; total time=  39.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=512; total time=  39.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=512; total time=  40.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=256; total time=  19.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=512; total time=  40.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=256; total time=  19.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=256; total time=  18.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=256; total time=  18.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=256; total time=  19.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   9.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   8.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   8.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   8.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   8.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time=  39.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time=  39.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time=  39.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time=  40.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time=  39.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  19.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  19.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  19.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  19.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  19.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   9.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   9.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   9.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   9.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   8.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time=  40.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time=  40.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time=  40.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time=  40.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time=  41.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  19.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  19.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  18.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  19.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   9.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  19.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   9.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   8.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   8.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   8.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time=  39.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time=  39.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time=  39.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time=  40.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time=  40.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=256; total time=  19.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=256; total time=  19.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=256; total time=  19.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=256; total time=  19.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=256; total time=  19.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   9.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   8.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   8.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   8.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   8.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=512; total time=  39.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=512; total time=  40.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=512; total time=  40.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=512; total time=  40.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=256; total time=  20.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=512; total time=  41.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=256; total time=  21.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=256; total time=  20.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=256; total time=  21.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   9.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=256; total time=  21.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   8.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   9.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   8.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   8.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=512; total time=  40.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=512; total time=  41.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=512; total time=  41.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=512; total time=  42.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=512; total time=  40.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=256; total time=  20.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=256; total time=  19.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=256; total time=  19.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=256; total time=  18.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=256; total time=  19.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   9.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  10.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  11.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  12.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  12.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=512; total time=  45.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=512; total time=  46.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=512; total time=  51.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=512; total time=  51.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=512; total time=  51.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=256; total time=  28.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=256; total time=  28.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=256; total time=  26.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=256; total time=  26.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=256; total time=  27.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   9.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   9.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   9.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   8.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   9.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=512; total time=  46.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=512; total time=  47.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=512; total time=  47.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=512; total time=  48.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=512; total time=  49.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=256; total time=  27.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=256; total time=  26.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=256; total time=  28.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=256; total time=  26.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=256; total time=  25.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  12.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  11.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  12.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  12.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=512; total time=  48.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  13.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=512; total time=  46.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=512; total time=  46.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=512; total time=  45.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=512; total time=  45.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=256; total time=  28.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=256; total time=  28.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=256; total time=  27.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=256; total time=  28.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=256; total time=  27.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  14.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  13.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  14.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  11.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=  11.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=512; total time=  55.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=512; total time=  56.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=512; total time=  56.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=256; total time=  26.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=512; total time=  56.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=512; total time=  56.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=256; total time=  25.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=256; total time=  25.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=256; total time=  26.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=256; total time=  27.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  12.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  14.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  13.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  13.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  12.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time=  56.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time= 1.0min
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  31.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time=  60.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  31.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time= 1.0min
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time= 1.0min
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  30.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  31.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.2s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  28.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  13.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  12.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  11.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time=  57.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time=  57.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time=  57.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time=  57.8s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  28.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time=  57.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  27.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  27.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  11.6s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  26.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  25.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  11.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  11.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  11.7s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  11.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time=  53.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time=  54.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time=  55.3s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time=  55.0s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time=  56.1s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=256; total time=  28.9s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=256; total time=  28.5s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=256; total time=  29.4s
# [CV] END class_weight=balanced, criterion=gini, max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=256; total time=  28.0s
# ...
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=256; total time=  34.2s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=256; total time=  34.6s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  15.5s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  13.8s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  14.1s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  13.5s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=  14.1s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=5, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  32.3s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  31.8s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  31.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  32.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  13.3s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=256; total time=  31.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  14.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  14.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  14.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=  14.1s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=1, min_samples_split=10, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  32.3s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  33.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  32.8s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  33.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=256; total time=  33.5s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  14.3s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  14.1s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  14.6s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  14.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=  14.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=2, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=256; total time=  34.2s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=256; total time=  33.9s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=256; total time=  33.2s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=256; total time=  33.2s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=256; total time=  33.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  14.3s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  13.9s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  13.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  14.5s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=  14.1s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=5, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=256; total time=  33.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=256; total time=  32.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=256; total time=  33.8s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=256; total time=  33.5s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  14.2s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=256; total time=  33.6s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  14.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  13.8s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  14.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=  14.1s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=2, min_samples_split=10, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=256; total time=  32.6s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=256; total time=  32.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=256; total time=  32.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=256; total time=  31.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=256; total time=  32.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  14.2s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  13.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  13.8s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  13.5s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  14.3s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=2, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=256; total time=  32.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=256; total time=  32.5s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=256; total time=  31.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=256; total time=  32.5s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=256; total time=  32.5s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  14.5s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  14.2s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  14.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  13.9s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  14.1s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=5, n_estimators=512; total time= 1.1min
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=256; total time=  33.5s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=256; total time=  32.5s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=256; total time=  32.2s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=256; total time=  30.0s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=256; total time=  29.9s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=512; total time=  50.7s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=512; total time=  49.3s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=512; total time=  49.8s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=512; total time=  48.4s
# [CV] END class_weight=None, criterion=log_loss, max_depth=30, min_samples_leaf=4, min_samples_split=10, n_estimators=512; total time=  44.7s
# Best parameters found by GridSearchCV: {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 512}
# Best cross-validated F1 score: 0.646219125115989

# %% [markdown]
# Best parameters found by GridSearchCV: {'class_weight': 'balanced', 'criterion': 'entropy', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 512}
# Best cross-validated F1 score: 0.646219125115989

# %%
# Compute performance metrics and confusion matrix
accuracy = accuracy_score(y_val, y_pred)
precision = precision_score(y_val, y_pred)
recall = recall_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred)
conf_matrix = confusion_matrix(y_val, y_pred)

# Print results
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1: {f1}')
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# Accuracy: 0.9485854540757008
# Precision: 0.6324143692564745
# Recall: 0.6801437556154537
# F1: 0.6554112554112554
# Confusion Matrix:
# [[13929   440]
#  [  356   757]]

# %%
# Split train and validation set
# X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=17, stratify=y)'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 512
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=17, stratify=y)

# Set model parameters and train
model = RandomForestClassifier(criterion='entropy', random_state=19, class_weight='balanced', min_samples_leaf=1, min_samples_split=10, n_estimators=512)
model.fit(X_train, y_train)

# Evaluate model on validation set
y_pred = model.predict(X_val)

# Compute performance metrics and confusion matrix
accuracy = accuracy_score(y_val, y_pred)
precision = precision_score(y_val, y_pred)
recall = recall_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred)
conf_matrix = confusion_matrix(y_val, y_pred)

# Print results
print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'recall: {recall}')
print(f'F1: {f1}')
print('Confusion Matrix:')
print(conf_matrix)
# Out:
# Accuracy: 0.9523963312233562
# Precision: 0.6516072980017377
# recall: 0.6906077348066298
# F1: 0.6705409029950827
# Confusion Matrix:
# [[13995   401]
#  [  336   750]]

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import cross_validate

# Set model parameters
model = RandomForestClassifier(criterion='entropy', random_state=19, class_weight='balanced', 
                               min_samples_leaf=1, min_samples_split=10, n_estimators=512)

# Define scoring metrics
scoring = {
    'accuracy': 'accuracy',
    'precision': make_scorer(precision_score),
    'recall': make_scorer(recall_score),
    'f1': make_scorer(f1_score)
}

# Perform cross-validation with 5 folds
scores = cross_validate(model, X, y, cv=5, scoring=scoring)

# Print results
print(f"Mean Accuracy: {scores['test_accuracy'].mean()}")
print(f"Mean Precision: {scores['test_precision'].mean()}")
print(f"Mean Recall: {scores['test_recall'].mean()}")
print(f"Mean F1 Score: {scores['test_f1'].mean()}")

# %%
# Create feature variables and target variables
X_test = df_test.drop(columns=['ID_CLIENTE', 'SAFRA_REF']).copy()

# Make predictions
y_pred_test = model.predict_proba(X_test)[:, 1]

# Create final data frame and save it
df_predictions = df_test[["ID_CLIENTE", "SAFRA_REF"]].copy()
df_predictions['INADIMPLENTE'] = y_pred_test.copy()
df_predictions
# df_predictions.to_csv(f'{clean_folder}/df_predictions.csv')
# Out:
#                 ID_CLIENTE SAFRA_REF  INADIMPLENTE
# 0      5058298901476893676   2021-07      0.015625
# 1      5058298901476893676   2021-07      0.019531
# 2      5058298901476893676   2021-07      0.019531
# 3      5058298901476893676   2021-07      0.023438
# 4       274692171162531764   2021-07      0.011719
# ...                    ...       ...           ...
# 11822   780065359501679358   2021-11      0.027344
# 11823   121658372387044248   2021-11      0.117188
# 11824   798425422240919854   2021-11      0.062500
# 11825  7828430488099134389   2021-11      0.007812
# 11826  7828430488099134389   2021-11      0.003906
#
# [11827 rows x 3 columns]

# %%
df_predictions[df_predictions['INADIMPLENTE']>=0.5]
# Out:
#                 ID_CLIENTE SAFRA_REF  INADIMPLENTE
# 268    3421433989501830226   2021-07      0.824219
# 488    8229446069655666941   2021-07      0.617188
# 491    8229446069655666941   2021-07      0.613281
# 822    5714540197488862003   2021-07      0.742188
# 1054   1156053485989336481   2021-07      0.628906
# ...                    ...       ...           ...
# 10657  4008627434689715639   2021-11      0.585938
# 10762  8733525963966339207   2021-11      0.769531
# 11603   683445437387317282   2021-11      0.550781
# 11658  8646472172649019955   2021-11      0.585938
# 11811   957773253650890560   2021-11      0.582031
#
# [83 rows x 3 columns]

# %%
((df_predictions[df_predictions['INADIMPLENTE']>0.5].shape[0])/df_predictions.shape[0])*100
# Out:
# 0.7017840534370507

# %%
((df_train[df_train['INADIMPLENTE']==1].shape[0])/df_train.shape[0])*100
# Out:
# 7.01607069036792
